# %%
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os
import cv2
from keras.preprocessing import image
current_dir = os.getcwd()
image_dir = os.path.join(current_dir, 'images')

# %%
#img_path = 'images/Z_elephant.jpg'
img_path = 'images/Z3_Koala.jpg'
img_path = 'images/Elephant2.jpg'
img_path = 'images/zebra.jpeg'
img_path = 'images/llama.jpeg'
img_path = 'images/Z5_zororocco.jpg'
img = image.load_img(img_path, target_size=(200, 200))

# %%
lines = 200
rows  = 200
chanal = 3

# %%
x = np.linspace(0,lines-1,lines)

# %%
#x

# %%
x.size
# Out:
# 200

# %%
y = np.linspace(0,rows-1,rows)

# %%
#y

# %%
y.size
# Out:
# 200

# %%
def poly_fx(x, y):
    #
    #
    #    switch(fmode){ 
    #    case 0:
    fx = x**2*y + y**2 + 8;
    #    case 1:
    fx = 0.8999*(1.0*x**1.0 + 0.355*y**1.0 + 0.500001);
    #    case 2:
    #fx = 1.9*(1.0*x**1.0 + 0.0*y**1.0 + 0.100001);
    #    case 3
    #        fx = 200 * 1/(0 + 1.0*x**1.0 + 0.0*y**1.0 + 0.100001);
    #    default:
    #fx = 1.0*(1.0*x**1.0 + 0.0*y**1.0 + 0.100001) 
            #return "nothing";
     #   };
    return fx

# %%
def poly_fy(x, y):
    fy = x**2*y + y**2 + 8
    fy = 0.8999*(0.344*x**1.0 + 1.0*y**1.0 + 1.70001) 
    #fy = 1.0*(0.0*x**1.0 + 1.0*y**1.0 + 0.00001)
    #fy = 1.9*(0.0*x**1.0 + 1.0*y**1.0 + 0.00001)
    #fy = 200 * 1/(0 + 0.0*x**1.0 + 1.0*y**1.0 + 0.10001)
    return fy

# %% [markdown]
# F = hG
#     F = 0.5 G
# G = F/h
#     G = F/0.5

# %%
yt = np.array([])
print(yt.size)
xt = np.array([])
print(xt.size)
for j in range (0,y.size):
    for i in range  (0,x.size):
        yt = np.append(yt, [[poly_fy(x[i], y[j])]])
        
        xt = np.append(xt, [[poly_fx(x[i], y[j])]])
        
        
print(yt.size, xt.size)
# Out:
# 0
# 0
# 40000 40000

# %%
xt.shape
# Out:
# (40000,)

# %%
xt = np.reshape(xt, (rows,lines))

# %%
xt.shape
# Out:
# (200, 200)

# %%
yt = np.reshape(yt, (rows,lines))

# %%
yt.shape
# Out:
# (200, 200)

# %%
xt[0,:]
# Out:
# array([  0.4499509,   1.3498509,   2.2497509,   3.1496509,   4.0495509,
#          4.9494509,   5.8493509,   6.7492509,   7.6491509,   8.5490509,
#          9.4489509,  10.3488509,  11.2487509,  12.1486509,  13.0485509,
#         13.9484509,  14.8483509,  15.7482509,  16.6481509,  17.5480509,
#         18.4479509,  19.3478509,  20.2477509,  21.1476509,  22.0475509,
#         22.9474509,  23.8473509,  24.7472509,  25.6471509,  26.5470509,
#         27.4469509,  28.3468509,  29.2467509,  30.1466509,  31.0465509,
#         31.9464509,  32.8463509,  33.7462509,  34.6461509,  35.5460509,
#         36.4459509,  37.3458509,  38.2457509,  39.1456509,  40.0455509,
#         40.9454509,  41.8453509,  42.7452509,  43.6451509,  44.5450509,
#         45.4449509,  46.3448509,  47.2447509,  48.1446509,  49.0445509,
#         49.9444509,  50.8443509,  51.7442509,  52.6441509,  53.5440509,
#         54.4439509,  55.3438509,  56.2437509,  57.1436509,  58.0435509,
# ...

# %%
yt[0][0:lines]
# Out:
# array([ 1.529839 ,  1.8394046,  2.1489702,  2.4585358,  2.7681014,
#         3.077667 ,  3.3872326,  3.6967982,  4.0063638,  4.3159294,
#         4.625495 ,  4.9350606,  5.2446262,  5.5541918,  5.8637574,
#         6.173323 ,  6.4828886,  6.7924542,  7.1020198,  7.4115854,
#         7.721151 ,  8.0307166,  8.3402822,  8.6498478,  8.9594134,
#         9.268979 ,  9.5785446,  9.8881102, 10.1976758, 10.5072414,
#        10.816807 , 11.1263726, 11.4359382, 11.7455038, 12.0550694,
#        12.364635 , 12.6742006, 12.9837662, 13.2933318, 13.6028974,
#        13.912463 , 14.2220286, 14.5315942, 14.8411598, 15.1507254,
#        15.460291 , 15.7698566, 16.0794222, 16.3889878, 16.6985534,
#        17.008119 , 17.3176846, 17.6272502, 17.9368158, 18.2463814,
#        18.555947 , 18.8655126, 19.1750782, 19.4846438, 19.7942094,
#        20.103775 , 20.4133406, 20.7229062, 21.0324718, 21.3420374,
#        21.651603 , 21.9611686, 22.2707342, 22.5802998, 22.8898654,
# ...

# %%
for i in range (0,rows):
    plt.scatter(np.arange(0,lines),yt[i][0:lines])
    plt.plot(np.arange(0,lines),yt[i][:])
    #plt.scatter(np.arange(0,lines),xt[i][0:lines])
    plt.plot(np.arange(0,lines),xt[i][:])


plt.show()

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0xBD50C88>

# %%
ix = image.img_to_array(img)

# %%
ix.shape
# Out:
# (200, 200, 3)

# %%
#ix.reshape(220,220,3)

# %%
#print(x[0])

# %%
ix[0,0,0:3]
# Out:
# array([159., 173.,  96.], dtype=float32)

# %%
ix[0][2]
# Out:
# array([154., 155., 113.], dtype=float32)

# %%
wrp = np.zeros(220*220*3)
wrp
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
wrp.shape
# Out:
# (145200,)

# %%
wrp = np.reshape(wrp, (220,220,3))
wrp.shape
# Out:
# (220, 220, 3)

# %%
 wrp[0][0][0:3] = ix[0][0][0:3]

# %%
wrp[0][0][0:3]
# Out:
# array([159., 173.,  96.])

# %%
int(xt[0,7])
# Out:
# 6

# %%
for j in range (0,rows):
    for i in range (0,lines):
        if (int(yt[j][i]) < 200) and (int(xt[j][i]) < 200): 
            wrp[j+10][i+10][0:3] = ix[int(yt[j][i])][int(xt[j][i])][0:3]
            #wrp[j][i] = [11,22,33]

# %%
wrp[0][0:4]
# Out:
# array([[159., 173.,  96.],
#        [  0.,   0.,   0.],
#        [  0.,   0.,   0.],
#        [  0.,   0.,   0.]])

# %%
#wrp[0]

# %%
iw = image.array_to_img(wrp)

# %%
iw
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0xDCA8DD8>
